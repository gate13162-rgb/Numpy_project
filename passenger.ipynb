# %%
import pandas as pd
import pip

# !pip install scikit-learn


from sklearn.preprocessing import LabelEncoder, RobustScaler

data = {
    'Gender': ['Male', 'Female', 'Female', 'Male', 'Female'],
    'City': ['Mumbai', 'Delhi', 'Chennai', 'Mumbai', 'Delhi'],
    'Size': ['Small', 'Large', 'Medium', 'Large', 'Small'],
    'Age': [25, 45, 32, 60, 28],
    'Fare': [15, 300, 85, 450, 20]
}

df = pd.DataFrame(data)

# Label Encoding
le = LabelEncoder()
df['Gender'] = le.fit_transform(df['Gender'])

# City -> One-Hot Encoding 
df = pd.get_dummies(df, columns=['City'], drop_first=True)

# Size -> Manual Mapping
size_mapping = {'Small': 0, 'Medium': 1, 'Large': 2}
df['Size'] = df['Size'].map(size_mapping)

scaler = RobustScaler()
df[['Age', 'Fare']] = scaler.fit_transform(df[['Age', 'Fare']])

print(df)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in c:\users\neela\appdata\roaming\python\python311\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\neela\appdata\roaming\python\python311\site-packages (from scikit-learn) (2.3.5)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\neela\appdata\roaming\python\python311\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\neela\appdata\roaming\python\python311\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\neela\appdata\roaming\python\python311\site-packages (from scikit-learn) (3.6.0)
#    Gender  Size       Age      Fare  City_Delhi  City_Mumbai
# 0       1     0 -0.411765 -0.250000       False         True
# 1       0     2  0.764706  0.767857        True        False
# 2       0     1  0.000000  0.000000       False        False
# 3       1     2  1.647059  1.303571       False         True
# 4       0     0 -0.235294 -0.232143        True        False
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
