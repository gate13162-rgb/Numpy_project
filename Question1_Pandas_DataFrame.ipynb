# %%
import pandas as pd

students_data = pd.read_csv('Students.csv')
print(students_data,'\n')

df=pd.read_csv('Students.csv')
print(df, '\n')

df.to_csv('Students.csv', index=False)

df_new=pd.read_csv('Students.csv',header=None)
print(df_new, '\n')



df_new=pd.read_csv('Students.csv', delimiter='|')
print(df_new ,'\n')

print(df_new.head(3),'\n')

print(df_new.describe(),'\n')

print(df_new.shape,'\n')

print(df_new.info(),'\n')

print(df_new.dtypes,'\n')
# Out:
#   StudentID|Name|Age|Marks|Grade
# 0              101|Alice|20|88|A
# 1                102|Bob|21|75|B
# 2            103|Charlie|19|92|A
# 3              104|Diana|22|65|C
# 4              105|Ethan|20|78|B
# 5              106|Fiona|21|85|A
# 6             107|George|23|70|B
# 7             108|Hannah|19|95|A
# 8               109|Ivan|22|60|C
# 9              110|Julia|20|80|B
#
#   StudentID|Name|Age|Marks|Grade
# 0              101|Alice|20|88|A
# 1                102|Bob|21|75|B
# 2            103|Charlie|19|92|A
# 3              104|Diana|22|65|C
# 4              105|Ethan|20|78|B
# 5              106|Fiona|21|85|A
# 6             107|George|23|70|B
# 7             108|Hannah|19|95|A
# 8               109|Ivan|22|60|C
# 9              110|Julia|20|80|B
#
#                                  0
# 0   StudentID|Name|Age|Marks|Grade
# 1                101|Alice|20|88|A
# 2                  102|Bob|21|75|B
# 3              103|Charlie|19|92|A
# 4                104|Diana|22|65|C
# ...

# %% [markdown]
# # Task
# Reload the 'Students.csv' file, using '|' as the delimiter, to correctly align the columns in the 'df' DataFrame. Then, display the first few rows of the corrected DataFrame to confirm the proper column alignment, ensuring the data is ready for analysis.

# %% [markdown]
# ## Align DataFrame Columns
#
# ### Subtask:
# Reload the 'Students.csv' file, explicitly specifying the '|' character as the delimiter to correctly separate the columns in the 'df' DataFrame.

# %% [markdown]
# **Reasoning**:
# The subtask requires reloading the 'Students.csv' file with the correct delimiter. This step will use `pd.read_csv()` and specify `delimiter='|'` to correctly parse the data into the `df` DataFrame, and then display the head of the DataFrame to verify the correct loading.

# %%
df = pd.read_csv('Students.csv', delimiter='|')
print(df.head())
# Out:
#    StudentID     Name  Age  Marks Grade
# 0        101    Alice   20     88     A
# 1        102      Bob   21     75     B
# 2        103  Charlie   19     92     A
# 3        104    Diana   22     65     C
# 4        105    Ethan   20     78     B

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Confirm that the data in the `df` DataFrame is now properly aligned and ready for further analysis.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# Yes, the data in the `df` DataFrame is now properly aligned and ready for further analysis.
#
# ### Data Analysis Key Findings
# *   The `Students.csv` file was successfully reloaded into the `df` DataFrame using the pipe symbol (`|`) as the delimiter.
# *   The `df` DataFrame now displays correctly aligned columns, including 'StudentID', 'Name', 'Age', 'Marks', and 'Grade', confirming the intended application of the delimiter.
#
# ### Insights or Next Steps
# *   The data preprocessing step of ensuring correct column alignment is complete, and the DataFrame is now in a suitable format for subsequent analytical tasks.
